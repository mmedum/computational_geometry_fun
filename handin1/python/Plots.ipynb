# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
# %matplotlib inline

# %%
header_names = ['n', 'step', 'miliseconds']

# %%
first_df = pd.read_csv('../data/clang4.0_core_i7.csv', names = header_names)
second_df = pd.read_csv('../data/clang38_204mb_core_i7.csv', names = header_names)

# %%
first_df = first_df[first_df['miliseconds'] > 0]
second_df = second_df[second_df['miliseconds'] > 0]

# %%
n_first_grouped = first_df.groupby(first_df['n'])
n_second_grouped = second_df.groupby(second_df['n'])

# %%
for title, group in n_first_grouped:
    ax = group.plot(x='step', y='miliseconds', title='n={}'.format(title))
    fig = ax.get_figure()
    fig.savefig('n={}_first.png'.format(title))

# %%
for title, group in n_second_grouped:
    ax = group.plot(x='step', y='miliseconds', title='n={}'.format(title))
    fig = ax.get_figure()
    fig.savefig('n={}_second.png'.format(title))

# %%
step_first_grouped = first_df.groupby(first_df['step'])
step_second_grouped = second_df.groupby(second_df['step'])

# %%
for title, group in step_first_grouped:
    ax = group.plot(x='n', y='miliseconds', title='step={}'.format(title))
    fig = ax.get_figure()
    fig.savefig('step={}_first.png'.format(title))

# %%
for title, group in step_second_grouped:
    ax = group.plot(x='n', y='miliseconds', title='step={}'.format(title))
    fig = ax.get_figure()
    fig.savefig('step={}_second.png'.format(title))

# %%
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
from mpl_toolkits.mplot3d import Axes3D

# %%
fig = plt.figure()
ax = Axes3D(fig)
ax.plot_trisurf(first_df.n, first_df.step, first_df.miliseconds)
ax.view_init(30, -32)
plt.show()
fig.savefig('3d.png')

# %%
fig = plt.figure()
ax = Axes3D(fig)
ax.plot_trisurf(first_df.n, first_df.step, first_df.miliseconds)
ax.view_init(30, -32)
plt.show()
fig.savefig('3d.png')

# %%
fig = plt.figure()
ax = plt.gca()
ax.scatter(first_df.n, first_df.step, s=first_df.miliseconds , c='blue', alpha=0.2, edgecolors='none')
ax.set_yscale('log')
ax.set_xscale('log')
plt.xlabel('n')
plt.ylabel('step')
fig.savefig('scatterplt.png')

# %%
fig = plt.figure()
ax = plt.gca()
ax.scatter(second_df.n, second_df.step, s=second_df.miliseconds , c='blue', alpha=0.2, edgecolors='none')
ax.set_yscale('log')
ax.set_xscale('log')
plt.xlabel('n')
plt.ylabel('step')
fig.savefig('scatterplt.png')
