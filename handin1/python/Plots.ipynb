# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
# %matplotlib inline

# %%
header_names = ['n', 'step', 'miliseconds']

# %%
first_df = pd.read_csv('../data/clang4.0_core_i7.csv', names = header_names)
second_df = pd.read_csv('../data/clang38_204mb_core_i7.csv', names = header_names)

# %%
first_df = first_df[first_df['miliseconds'] > 0]
second_df = second_df[second_df['miliseconds'] > 0]

# %%
n_first_grouped = first_df.groupby(first_df['n'])
n_second_grouped = second_df.groupby(second_df['n'])

# %%
n_first_grouped.plot(x='step', y='miliseconds')
# Out:
# n
# 65568        Axes(0.125,0.125;0.775x0.755)
# 131136       Axes(0.125,0.125;0.775x0.755)
# 262272       Axes(0.125,0.125;0.775x0.755)
# 524544       Axes(0.125,0.125;0.775x0.755)
# 1049088      Axes(0.125,0.125;0.775x0.755)
# 2098176      Axes(0.125,0.125;0.775x0.755)
# 4196352      Axes(0.125,0.125;0.775x0.755)
# 8392704      Axes(0.125,0.125;0.775x0.755)
# 16785408     Axes(0.125,0.125;0.775x0.755)
# 33570816     Axes(0.125,0.125;0.775x0.755)
# 67141632     Axes(0.125,0.125;0.775x0.755)
# 134283264    Axes(0.125,0.125;0.775x0.755)
# 268566528    Axes(0.125,0.125;0.775x0.755)
# dtype: object

# %%
n_second_grouped.plot(x='step', y='miliseconds')
# Out:
# n
# 16392        Axes(0.125,0.125;0.775x0.755)
# 32784        Axes(0.125,0.125;0.775x0.755)
# 65568        Axes(0.125,0.125;0.775x0.755)
# 131136       Axes(0.125,0.125;0.775x0.755)
# 262272       Axes(0.125,0.125;0.775x0.755)
# 524544       Axes(0.125,0.125;0.775x0.755)
# 1049088      Axes(0.125,0.125;0.775x0.755)
# 2098176      Axes(0.125,0.125;0.775x0.755)
# 4196352      Axes(0.125,0.125;0.775x0.755)
# 8392704      Axes(0.125,0.125;0.775x0.755)
# 16785408     Axes(0.125,0.125;0.775x0.755)
# 33570816     Axes(0.125,0.125;0.775x0.755)
# 67141632     Axes(0.125,0.125;0.775x0.755)
# 134283264    Axes(0.125,0.125;0.775x0.755)
# 268566528    Axes(0.125,0.125;0.775x0.755)
# dtype: object

# %%
step_first_grouped = first_df.groupby(first_df['step'])
step_second_grouped = second_df.groupby(second_df['step'])

# %%
step_first_grouped.plot(x='n', y='miliseconds')
# Out:
# step
# 1         Axes(0.125,0.125;0.775x0.755)
# 2         Axes(0.125,0.125;0.775x0.755)
# 4         Axes(0.125,0.125;0.775x0.755)
# 8         Axes(0.125,0.125;0.775x0.755)
# 16        Axes(0.125,0.125;0.775x0.755)
# 32        Axes(0.125,0.125;0.775x0.755)
# 64        Axes(0.125,0.125;0.775x0.755)
# 128       Axes(0.125,0.125;0.775x0.755)
# 256       Axes(0.125,0.125;0.775x0.755)
# 512       Axes(0.125,0.125;0.775x0.755)
# 1024      Axes(0.125,0.125;0.775x0.755)
# 2048      Axes(0.125,0.125;0.775x0.755)
# 4096      Axes(0.125,0.125;0.775x0.755)
# 8192      Axes(0.125,0.125;0.775x0.755)
# 16384     Axes(0.125,0.125;0.775x0.755)
# 32768     Axes(0.125,0.125;0.775x0.755)
# 65536     Axes(0.125,0.125;0.775x0.755)
# 131072    Axes(0.125,0.125;0.775x0.755)
# 262144    Axes(0.125,0.125;0.775x0.755)
# 524288    Axes(0.125,0.125;0.775x0.755)
# dtype: object

# %%
step_second_grouped.plot(x='n', y='miliseconds')
# Out:
# step
# 1         Axes(0.125,0.125;0.775x0.755)
# 2         Axes(0.125,0.125;0.775x0.755)
# 4         Axes(0.125,0.125;0.775x0.755)
# 8         Axes(0.125,0.125;0.775x0.755)
# 16        Axes(0.125,0.125;0.775x0.755)
# 32        Axes(0.125,0.125;0.775x0.755)
# 64        Axes(0.125,0.125;0.775x0.755)
# 128       Axes(0.125,0.125;0.775x0.755)
# 256       Axes(0.125,0.125;0.775x0.755)
# 512       Axes(0.125,0.125;0.775x0.755)
# 1024      Axes(0.125,0.125;0.775x0.755)
# 2048      Axes(0.125,0.125;0.775x0.755)
# 4096      Axes(0.125,0.125;0.775x0.755)
# 8192      Axes(0.125,0.125;0.775x0.755)
# 16384     Axes(0.125,0.125;0.775x0.755)
# 32768     Axes(0.125,0.125;0.775x0.755)
# 65536     Axes(0.125,0.125;0.775x0.755)
# 131072    Axes(0.125,0.125;0.775x0.755)
# 262144    Axes(0.125,0.125;0.775x0.755)
# 524288    Axes(0.125,0.125;0.775x0.755)
# dtype: object
